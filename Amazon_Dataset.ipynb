# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Amazon_Sale_Report.csv', encoding= 'unicode_escape')

# %%
df.head(5)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.tail(5)
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128971  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  ...  \
# 128971     Amazon.in          Expedited    Shirt   XL        Shipped  ...
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped  ...
# 128973     Amazon.in          Expedited  Blazzer  XXL        Shipped  ...
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped  ...
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped  ...
#
#         currency  Amount  ship-city    ship-state ship-postal-code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
 df.drop(['New','PendingS'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
pd.isnull(df)
##checking null values:---
# Out:
#         index  Order ID   Date  Status  Fulfilment  Sales Channel  \
# 0       False     False  False   False       False          False
# 1       False     False  False   False       False          False
# 2       False     False  False   False       False          False
# 3       False     False  False   False       False          False
# 4       False     False  False   False       False          False
# ...       ...       ...    ...     ...         ...            ...
# 128971  False     False  False   False       False          False
# 128972  False     False  False   False       False          False
# 128973  False     False  False   False       False          False
# 128974  False     False  False   False       False          False
# 128975  False     False  False   False       False          False
#
#         ship-service-level  Category   Size  Courier Status    Qty  currency  \
# 0                    False     False  False           False  False     False
# ...

# %%
pd.isnull(df).sum()
##sum will give total values of null values
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               7800
# Amount                 7800
# ship-city                35
# ship-state               35
# ship-postal-code         35
# ship-country             35
# B2B                       0
# fulfilled-by          89713
# dtype: int64

# %%
df.shape
# Out:
# (128976, 19)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (37514, 19)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
## change datatype:---
##change ship-postal-code data float to int
df['ship-postal-code']=df['ship-postal-code'].astype('int')

# %%
##checking whether the data type change or not
df['ship-postal-code'].dtype
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  object
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
## change Data object to Date:----
df['Date']=pd.to_datetime(df['Date'])
# Out:
# C:\Users\Anwesa Panja\AppData\Local\Temp\ipykernel_20980\3712653620.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']=pd.to_datetime(df['Date'])

# %%
##check date will change or not...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  datetime64[ns]
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
## check all colums:---
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
##rename the columns:---
df.rename(columns={'Qty':'Quantity'})
# Out:
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 7            7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12          12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
# ...        ...                  ...        ...                           ...
# 128875  128874  405-4724097-1016369 2022-06-01  Shipped - Delivered to Buyer
# 128876  128875  403-9524128-9243508 2022-06-01                     Cancelled
# 128888  128887  405-6493630-8542756 2022-05-31  Shipped - Delivered to Buyer
# 128891  128890  407-0116398-1810752 2022-05-31                     Cancelled
# 128892  128891  403-0317423-9322704 2022-05-31  Shipped - Delivered to Buyer
#
# ...

# %%
## Describe() method returns (count,means,min max,std,25%,75%)
df.describe()
# Out:
#                index                           Date           Qty  \
# count   37514.000000                          37514  37514.000000
# mean    60953.809858  2022-05-11 07:56:47.303939840      0.867383
# min         0.000000            2022-03-31 00:00:00      0.000000
# 25%     27235.250000            2022-04-20 00:00:00      1.000000
# 50%     63470.500000            2022-05-09 00:00:00      1.000000
# 75%     91790.750000            2022-06-01 00:00:00      1.000000
# max    128891.000000            2022-06-29 00:00:00      5.000000
# std     36844.853039                            NaN      0.354160
#
#              Amount  ship-postal-code
# count  37514.000000      37514.000000
# mean     646.553960     463291.552754
# min        0.000000     110001.000000
# 25%      458.000000     370465.000000
# 50%      629.000000     500019.000000
# 75%      771.000000     600042.000000
# max     5495.000000     989898.000000
# std      279.952414     194550.425637

# %%
##but here describe uses for integer 
#for use of object we should use here (include='object') in method

# %%
df.describe(include='object')
# Out:
#                    Order ID                        Status Fulfilment  \
# count                 37514                         37514      37514
# unique                34664                            11          1
# top     171-5057375-2831560  Shipped - Delivered to Buyer   Merchant
# freq                     12                         28741      37514
#
#        Sales Channel ship-service-level Category   Size Courier Status  \
# count          37514              37514    37514  37514          37514
# unique             1                  1        8     11              3
# top        Amazon.in           Standard  T-shirt      M        Shipped
# freq           37514              37514    14062   6806          31859
#
#        currency  ship-city   ship-state ship-country fulfilled-by
# count     37514      37514        37514        37514        37514
# unique        1       4698           58            1            1
# ...

# %%
## use describe() for specific columns:---
df[['Qty','Amount']].describe()
# Out:
#                 Qty        Amount
# count  37514.000000  37514.000000
# mean       0.867383    646.553960
# std        0.354160    279.952414
# min        0.000000      0.000000
# 25%        1.000000    458.000000
# 50%        1.000000    629.000000
# 75%        1.000000    771.000000
# max        5.000000   5495.000000

# %%
## data cleaning done:---

# %%
## Now we analysing the data
#EDA

# %% [markdown]
# Exploratory Data Analysis

# %%
## 1st we check the column name

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
#Size

# %%
#using seaborn we do this:--
ax=sns.countplot(x='Size', data=df)

# %%
## For adding label we do this and create for loop
ax=sns.countplot(x='Size',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# NOTE:---- From above Graph you can see that most of the people buys M-size

# %% [markdown]
# Group By:--
# The groupby() function in Pandas is used to group data based on one and more columns in DataFrame

# %%
df.groupby(['Size'],as_index=False)['Qty'].sum().sort_values(by='Qty',ascending=False)
# Out:
#     Size   Qty
# 6      M  5905
# 5      L  5795
# 8     XL  5481
# 10   XXL  4465
# 0    3XL  3972
# 7      S  3896
# 9     XS  2191
# 4   Free   467
# 3    6XL   170
# 2    5XL   104
# 1    4XL    93

# %%
## For creating Graph we have to use barplot
S_Qty=df.groupby(['Size'],as_index=False)['Qty'].sum().sort_values(by='Qty',ascending=False)
sns.barplot(x='Size',y='Qty',data=S_Qty)
# Out:
# <Axes: xlabel='Size', ylabel='Qty'>

# %% [markdown]
# Note:--- From Above graph we can see that most of the Qty buys M-Size in the Sales

# %%
df.head(5)
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545 2022-04-30                     Cancelled
# 1       1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3       3  403-9615377-8133951 2022-04-30                     Cancelled
# 7       7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12     12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
#
#    Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0    Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1    Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
# 3    Merchant     Amazon.in           Standard  Blazzer    L     On the Way
# 7    Merchant     Amazon.in           Standard    Shirt    S        Shipped
# 12   Merchant     Amazon.in           Standard    Shirt   XS        Shipped
#
#     Qty currency  Amount   ship-city   ship-state  ship-postal-code  \
# ...

# %% [markdown]
# Courier Status

# %%
ax=sns.countplot(x='Courier Status',hue='Status',data=df)

# %%
## Here we cannot pass x and y value both

# %%
## For zooming the fig
#here we use figsize

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(x='Courier Status',hue='Status',data=df)
plt.show()

# %% [markdown]
# From that we can see that from the above graph the majority of the orders are shipped (Delivered to Buyer through the courier)

# %% [markdown]
# Histogram

# %%
df['Size'].hist()
# Out:
# <Axes: >

# %%
df.head(5)
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545 2022-04-30                     Cancelled
# 1       1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3       3  403-9615377-8133951 2022-04-30                     Cancelled
# 7       7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12     12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
#
#    Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0    Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1    Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
# 3    Merchant     Amazon.in           Standard  Blazzer    L     On the Way
# 7    Merchant     Amazon.in           Standard    Shirt    S        Shipped
# 12   Merchant     Amazon.in           Standard    Shirt   XS        Shipped
#
#     Qty currency  Amount   ship-city   ship-state  ship-postal-code  \
# ...

# %%
## We just find how much people buy Tshirt:---
## but ypu look that then we can see that catagory data type is objet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37514 entries, 0 to 128892
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               37514 non-null  int64
#  1   Order ID            37514 non-null  object
#  2   Date                37514 non-null  datetime64[ns]
#  3   Status              37514 non-null  object
#  4   Fulfilment          37514 non-null  object
#  5   Sales Channel       37514 non-null  object
#  6   ship-service-level  37514 non-null  object
#  7   Category            37514 non-null  object
#  8   Size                37514 non-null  object
#  9   Courier Status      37514 non-null  object
#  10  Qty                 37514 non-null  int64
#  11  currency            37514 non-null  object
#  12  Amount              37514 non-null  float64
#  13  ship-city           37514 non-null  object
#  14  ship-state          37514 non-null  object
# ...

# %%
## For changing data type:--
df['Category']=df['Category'].astype(str)

# %%
df.dtypes['Category']
# Out:
# dtype('O')

# %%
column_data=df['Category']
plt.figure(figsize=(10,5))
plt.hist(column_data,bins=30,edgecolor='Black')
plt.show()

# %%
# if we want to rotate x name then we use rotation 
plt.hist(column_data,bins=30,edgecolor='Black')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# So from here we can see from the graph the most of the buyers are T-shirt

# %%
df.head(5)
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545 2022-04-30                     Cancelled
# 1       1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3       3  403-9615377-8133951 2022-04-30                     Cancelled
# 7       7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12     12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
#
#    Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0    Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1    Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
# 3    Merchant     Amazon.in           Standard  Blazzer    L     On the Way
# 7    Merchant     Amazon.in           Standard    Shirt    S        Shipped
# 12   Merchant     Amazon.in           Standard    Shirt   XS        Shipped
#
#     Qty currency  Amount   ship-city   ship-state  ship-postal-code  \
# ...

# %%
df.columns['B2B']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.columns['B2B']
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5382, in Index.__getitem__(self, key)
#    5379     else:
#    5380         key = np.asarray(key, dtype=bool)
# -> 5382 result = getitem(key)
#    5383 # Because we ruled out integer above, we always get an arraylike here
#    5384 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df['B2B']

# %%
## checking B2B data by using pie chart
B2B_check=df['B2B'].value_counts()
B2B_check

# %%
## Now we are going to plot pie chat
plt.pie(B2B_check,labels=B2B_check,autopct='%1.1f%%')
plt.show()

# %%
## We can not segregate that which is true and which is false
#for that:-----
plt.pie(B2B_check,labels=B2B_check.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# we can see here that the maximum 99.3% of buyers are retailers and 0.8% are B2B buyers

# %%
## For which data are available or not we use scatter plot
#here we use 2 data for use this scatter plot
x_data=df['Category']
y_data=df['Size']
## for plotting the scatter plot
plt.scatter(x_data,y_data)
## for adding lebel
plt.xlabel('Category')
plt.ylabel('Size')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# how many byers we have per city

# %%
df.head(5)

# %%
df['ship-state']

# %%
## plot count of cities by store:---
plt.figure(figsize=(12,6))
sns.countplot(data=df,x='ship-state')
plt.xlabel('Ship-state')
plt.ylabel('Count')
plt.title('Distribution of State')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Note:-- From above Graph you can see that most of the buyers are Maharashtra State

# %%
Count_Ship_state=df['ship-state'].value_counts()
Count_Ship_state

# %%
Count_Ship_state=df['ship-state'].value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(data=df[df['ship-state'].isin(Count_Ship_state.index)],x='ship-state')
plt.xlabel('Ship-state')
plt.ylabel('Count')
plt.title('Distribution of State')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Note:-- From above Graph you can see that most of the buyers are Maharashtra State

# %% [markdown]
# Conclusion:---
# 1)The data analysis reveals that the bussiness has a significant Customer Base in Maharastha State.

# %% [markdown]
# 2) Mainly serves retailers,fullfill orders through Amazon

# %% [markdown]
# 3) Experience High demand for T-shirts and sees M-size as the perferred choich amon buyer.

# %%
df
# Out:
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 7            7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 12          12  405-5513694-8146768 2022-04-30  Shipped - Delivered to Buyer
# ...        ...                  ...        ...                           ...
# 128875  128874  405-4724097-1016369 2022-06-01  Shipped - Delivered to Buyer
# 128876  128875  403-9524128-9243508 2022-06-01                     Cancelled
# 128888  128887  405-6493630-8542756 2022-05-31  Shipped - Delivered to Buyer
# 128891  128890  407-0116398-1810752 2022-05-31                     Cancelled
# 128892  128891  403-0317423-9322704 2022-05-31  Shipped - Delivered to Buyer
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Amazon_Dataset.ipynb',
#  'Amazon_Sale_Report.csv',
#  'handwritten.model',
#  'img',
#  'model',
#  'OS--',
#  'Project_recognition_System(new).ipynb',
#  'Project_recognition_System.ipynb',
#  'train_1.csv']

# %%
df.to_csv('Amazon_Sale_Report_modified.csv', index=False)

# %%
from IPython.display import FileLink
FileLink('Amazon_Sale_Report_modified.csv')
# Out:
# C:\Users\Anwesa Panja\OneDrive\Desktop\project_1\Amazon_Sale_Report_modified.csv

# %%
import pandas as pd

df = pd.read_excel('Amazon_Sale_Report_modified.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel('Amazon_Sale_Report_modified.csv')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
# ...

# %%
df = pd.read_csv('Amazon_Sale_Report_modified.csv')

# %%
df = pd.read_excel('Amazon_Sale_Report_modified.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df = pd.read_excel('Amazon_Sale_Report_modified.xlsx')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
# ...

# %%
# Segment 1: Category-wise
category_seg = df.groupby('Category').sum(numeric_only=True)

# Segment 2: State-wise
state_seg = df.groupby('ship-state').sum(numeric_only=True)

# Segment 3: Status-wise
status_seg = df['Status'].value_counts()

# Segment 4: Fulfilment-wise
fulfilment_seg = df.groupby('Fulfilment').sum(numeric_only=True)

# Segment 5: Monthly Sales
df['Date'] = pd.to_datetime(df['Date'])
monthly_seg = df.groupby(df['Date'].dt.month).sum(numeric_only=True)

# Segment 6: Size-wise
size_seg = df.groupby('Size').sum(numeric_only=True)

# %%
with pd.ExcelWriter('Amazon_Segmented_Report.xlsx') as writer:
    df.to_excel(writer, sheet_name='Raw Data', index=False)
    category_seg.to_excel(writer, sheet_name='Category Analysis')
    state_seg.to_excel(writer, sheet_name='State Analysis')
    status_seg.to_excel(writer, sheet_name='Order Status')
    fulfilment_seg.to_excel(writer, sheet_name='Fulfilment Analysis')
    monthly_seg.to_excel(writer, sheet_name='Monthly Sales')
    size_seg.to_excel(writer, sheet_name='Size Analysis')

# %%
from IPython.display import FileLink
FileLink('Amazon_Segmented_Report.xlsx')
# Out:
# C:\Users\Anwesa Panja\OneDrive\Desktop\project_1\Amazon_Segmented_Report.xlsx
